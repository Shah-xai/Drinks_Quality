# %%
from ensure import ensure_annotations

# %%
from box import ConfigBox
jafar= ConfigBox({
    "name": "jafar",
    "age": 30,
    "email": "jafar@example.com"
})

# %%
jafar.name
# Out:
# 'jafar'
